# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-SH09/Data_Science/blob/main/Panorama_do_COVID_19_Mundo_%26_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Panorama do Covid-19, Uma Breve Análise Sobre Seus Efeitos no Mundo e no  Brasil.
#
# <center><img src="https://github.com/Gustavo-SH09/Dados-Covid-19/blob/main/fusion-medical-animation-eaggqoiddmg-unsplash-630x354.jpg?raw=true" height="450px"></center>
#
#
#
#
# ###O coronavírus (COVID-19) é uma doença infecciosa causada pelo vírus SARS-CoV-2.
# A maioria das pessoas que adoecem em decorrência da COVID-19 apresentam sintomas leves a moderados podendo recuperar-se sem tratamentos especiais. No entanto, algumas desenvolvem um quadro grave e precisam de atendimento médico. O fato central é, temos conquistado alguns avanços relacionados ao entendimento básico sobre a COVID-19, porem estes conhecimentos não tem uma abrangência mutua entre a população geral, pois ainda estamos em uma fase que podemos denominar como embrionária na relação de discernimento deste evento calamitoso em que nos encontramos.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/Gustavo-SH09/Imagens/fccb9a6c768ff6d279aad9a4c4a51e190114975f/Minist%C3%A9rio%20da%20Sa%C3%BAde%20(1).png"></center>
#
#
# \
#
# Até o momento atual, observa-se que cerca de oitenta porcento dos casos confirmados são assintomáticos e rápidos. A maioria das pessoas que se encaixam nesse grupo, se recuperam sem quaisquer sequelas.
# No entanto, quinze porcento das pessoas terão infecções graves e precisarão de oxigênio. O restante das pessoas, classificadas como infecções muito graves e precisarão de ventilação assistida, por meio de respiradores mecânicos em ambientes hospitalares.
#
# Outrossim, estamos vivenciando descobertas de novas variantes no decorrer desta situação, o que influencia diretamente aos dados relacionados ao COVID-19
#
# Com o objetivo de elevar a consciência situacional a respeito da COVID-19 no Brasil e no Mundo, irei realizar uma análise sobre os dados públicos da doença.

# %% [markdown]
# <center><img alt="Colaboratory logo" width="50%" src="https://raw.githubusercontent.com/Gustavo-SH09/Imagens/fccb9a6c768ff6d279aad9a4c4a51e190114975f/Minist%C3%A9rio%20da%20Sa%C3%BAde.png"></center>
#
#
#
#
# O covid-19 é um vírus que vem nos gerando muitas complicações dentre a humanidade nos causando milhares de mortes ao redor do mundo, nos levando a tomar medidas nunca administradas nas últimas décadas. Contudo, tivemos a situação em 2010 na qual tivemos contato com o H1N1, um vírus com uma mortalidade consideravelmente mais alta que o covid-19, porém não tem a mesma capacidade de contágio, subsequentemente causando menos óbitos. A grande questão é, nós acabamos tomando medidas nunca tomadas antes, sendo do âmbito financeiro, educacional, social, turístico e entre outros setores diversos que tiveram restrições impostas na tentativa de conter a contágio e amenizar o pânico instaurado na população ao redor do mundo.
# Outrossim, estamos inicialmente aprendendo a lidar com o vírus, com suas intermináveis variantes que vem se apresentando cada vez mais contagiosas, porém, o desenvolvimento de vacinas produzidas pelas grandes corporações farmacêuticas, juntamente com a suma importância de laboratórios de grandes universidades renomadas. O contorno desta situação pode estar se tornando visível, como a ponta de um iceberg, mas temos muito a percorrer ainda, com inúmeras adversidades inimagináveis.
# Portanto, a necessidade de lhes trazer uma análise de dados concretos sobre a situação atual nos auxilia neste processo, pois o discernimento e informações são o início de tudo.

# %% [markdown]
# Os dados utilizados para este projeto de pesquisa advêm de fontes publicas fornecidas pelo governo brasileiro. Os quais são incentivados pela lei de transparência. Neste Dataset estão contidos dados triviais para a realização desta análise, as quais serão realizadas posteriormente. Realizar estas pesquisas de cunho científico no intuito de apresentar dados sobre algo de forma mais translucida e de um discernimento mais acessível é altamente importante, porém, há algumas dificuldades em realizar uma pesquisa direcionada ao covid-19, devido as descobertas recentes, juntamente com suas inúmeras mutações que vem culminando em outras variantes. Subsequentemente, estas variantes geram no ser humano diversos sintomas diferentes do que originalmente conhecemos. Desta forma, há uma dificuldade imensurável em comportar fidedignamente todos os dados, sempre haverá algum desvio, por mínimo que seja.

# %% [markdown]
# #____**Biblioteca**
#
# Biblioteca informativa referente aos termos utilizados no DataSet(Arquivo)
#
# * iso_code = iso_code é o famoso iso 3166. Codigo usado para denominar nomes dos paises e dependências.
# * continent = Continente.
# * location = Localização.
# * date = Data.
# * notal_cases = Total de casos.
# * new_casos = Novos casos.
# * new_cases_smoothed = Novos casos suavizados.
# * total_deaths = Total de mortes.
# * new_deaths = Novas mortes.
# * new_deaths_smoothed = Novas mortes suavizadas
# * total_cases_per_million = total de casos por milhão
# * new_cases_per_million =  novos casos por milhão
# * new_cases_smoothed_per_million =  novos casos suavisados por milhão
# * total_deaths_per_million =  total de mortos por milhão
# * new_deaths_per_million = novas morte por milhão
# * new_deaths_smoothed_per_million = nova mortes suavizadas por milhão
# * reproduction_rate = Taxa de Reprodução
# * icu_patients = pacientes de UTI
# * icu_patients_per_million = pacientes de uti por milhão
# * hosp_patients = pacientes do hospital
# * hosp_patients_per_million = pacientes do hospital por milhão
# * weekly_icu_admissions = admição semelhante a UTI
# * weekly_icu_admissions_per_million = admição semelhante a UTI por milhão
# * weekly_hosp_admissions = admição semelahnte a hopitalar
# * weekly_hosp_adissions_per_million = admição semelahnte a hopitalar por milhão
# * new_tests = Novos testes
# * total_testes = total de testes
# * total_tests_per_thousand = total de testes por MIL.
# * new_tests_smoothed = novos testes suavizados.
# * new_testssmoothed_per_thousand = novos testes suavizados por milhão.
# * positive_rate = testes positivos
# * tests_per_case = testes por caso
# * tests_units = unidade de testes
# * total_vaccinations = total de vacinas
# * people_vacinations =  pessoas vacinadas
# * people_fully_vaccinated = pessoas totalmente vacinadas
# * total_boosters = reforços totais
# * new_vaccinations = novas vacinas
# * new_vaccinations_smoothed = novas vacinas suavizadas
# * total_vaccinations_per_hundred =  total de vacinas por centenas
# * people_vacinated_per_hundred = pessoas vaciandas por centena
# * people_fully_vaccinated_per_hundred = pessoas totalmente vacinadas por centena
# * total_boosters_per_hundred = total de reforços por centena
# * new_vaccinations_smooted_per_million = novas vacinas aprovadas por milhão
# * new_people_vaccinated_smoothed =  novas pessoas vacinadas
# * new_people_vaccinated_smoothed_per_hundred = novas pessoas vacinadas em casos suavizados
# * stringency_index =  indice de rigor
# * population = população
# * population_density = densidade populacional
# * median_age = idade media
# * aged_65_older = com 65 anos ou mais
# * aged_70_older = com 70 anos ou mais
# * gdp_per_capita = PIB(Produto Inerno Bruto) per capita
# * extreme_poverty = Pobreza extrema
# * cardiovasc_death_rate = taxa de morte cardiovascular
# * diabetes_prevalence = prevalencia de diabeticos
# * female_smokers = mulheres fumantes
# * male_smokers = homens fumantes
# * handwashing_facilities = unidade de higienização das maos
# * hospital_beds_per_thousand = leitos hospitalares por mil
# * life_expectancy = expectativa de vida
# * human_develompment_index = indice de desenvolvimento humano
# * excess_mortality_cumulative_absolute = excesso de mortalidade absoluta acumulada
# * excess_mortality_cumulative = excesso de mortalidade acumulada
# * excess_mortality = excesso de mortalidade
# * excess_mortality_cumulative_per_million = excesso de mortalidade acumulada por milhão.

# %% [markdown]
# ###Inicialmente faremos a importação das Bibliotecas necessárias para a manipulação de dados. Posteriormente, trazendo o dataset já ancorado a nuvem, assim, facilitando sua visualização e utilização de tal.

# %%
# iportando bibliotecas necessárias para a manipulação de dados

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# importando dataframe

df = pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv")

# %%
# analisando numericamente o formato do arquivo
print('O arquivo tem {} entradas e {} atributos!'.format(df.shape[0], df.shape[1]))
# Out:
# O arquivo tem 166789 entradas e 67 atributos!

# %% [markdown]
# Abaixo, estaremos verificando as primeiras entradas de dados no arquivo, para que assim, tenhamos uma noção de onde podemos partir na análise.

# %%
# obtendo uma pré-visualizção do topo do arquivo
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# A seguir, há informações das ultimas entradas contidas no arquivo, para que assim abtivesse uma noção do tamanho temporal ao qual os dados estão.

# %%
# visualizando as ultimas entradas de dados da tabela, podendo assim, obter uma consciencia referente as datas que estamos analisando

df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 166784      ZWE    Africa  Zimbabwe  2022-03-03     237503.0        0.0
# 166785      ZWE    Africa  Zimbabwe  2022-03-04     238739.0     1236.0
# 166786      ZWE    Africa  Zimbabwe  2022-03-05     239019.0      280.0
# 166787      ZWE    Africa  Zimbabwe  2022-03-06     239209.0      190.0
# 166788      ZWE    Africa  Zimbabwe  2022-03-07     239710.0      501.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 166784             362.286        5396.0         0.0                0.857
# 166785             467.429        5397.0         1.0                0.714
# 166786             459.429        5397.0         0.0                0.571
# 166787             486.571        5399.0         2.0                0.857
# 166788             475.714        5399.0         0.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %% [markdown]
# Ao extrairmos o nome denominado para cada coluna do arquivo, podemos começar a relacionar os dados.

# %%
# Extraindo o o nome das colunas, para que assim possamos ter uma ideia de associação de dados
df.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
# ...

# %% [markdown]
# Na célula abaixo, estamos identificando o tipos de variaveis do dataset.

# %%
# identificando os tipos de variáveis
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# human_development_index                    float64
# excess_mortality_cumulative_absolute       float64
# excess_mortality_cumulative                float64
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# Length: 67, dtype: object

# %% [markdown]
# #Valores Ausentes

# %% [markdown]
# Ao lidar com valores ausentes, temos a possibilidade de apresentar o dataset com o resultado dos dados, lhe questionando se os valores são **NULOS**. Ao retornar a palavra `False` no dataset em evidencia abaixo, significa que o valor contido naquela lacuna em especifico NÃO é nulo e consequentemente a expressão `True` representara os valores ausentes

# %%
#  verificando a quantidade de valores ausentes
df.isnull()
# Out:
#         iso_code  continent  location   date  total_cases  new_cases  \
# 0          False      False     False  False        False      False
# 1          False      False     False  False        False      False
# 2          False      False     False  False        False      False
# 3          False      False     False  False        False      False
# 4          False      False     False  False        False      False
# ...          ...        ...       ...    ...          ...        ...
# 166784     False      False     False  False        False      False
# 166785     False      False     False  False        False      False
# 166786     False      False     False  False        False      False
# 166787     False      False     False  False        False      False
# 166788     False      False     False  False        False      False
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %% [markdown]
# Juntamente com o questionamento dos valores nulos, fazemos a soma de todos, assim obtemos de forma numérica a quantidade de tais.

# %%
#  verificando a quantidade de valores ausentes numericamente somados
df.isnull().sum()
# Out:
# iso_code                                        0
# continent                                    9982
# location                                        0
# date                                            0
# total_cases                                  3040
#                                             ...
# human_development_index                     30158
# excess_mortality_cumulative_absolute       161093
# excess_mortality_cumulative                161093
# excess_mortality                           161093
# excess_mortality_cumulative_per_million    161093
# Length: 67, dtype: int64

# %% [markdown]
# Ao vermos as porcentagens de valores ausentes de casa colunas, podemos analisar quais iremos priorizar na substituição de tais valores. Tal lista também serve para averiguar se após a alteração, ainda há algum valor ausente na coluna.

# %%
#Identificando a porcentagem de ddos ausentes presentesno dataset

df.isnull().sum() / df.shape[0]

(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# weekly_icu_admissions_per_million          0.967252
# weekly_icu_admissions                      0.967252
# excess_mortality_cumulative_per_million    0.965849
# excess_mortality                           0.965849
# excess_mortality_cumulative                0.965849
#                                              ...
# total_cases                                0.018227
# population                                 0.006457
# date                                       0.000000
# location                                   0.000000
# iso_code                                   0.000000
# Length: 67, dtype: float64

# %% [markdown]
# #Analisando a presença de Outliers

# %% [markdown]
# ##Transformando em datetime
#
# verificamos anteriormente que a coluna `date` não está no formato datetime. Para que possa se explorar essas variaveis, iremos transformar-la para o formato datetime.

# %%
# Transformando a coluna `date` em `datetime`

df.date = pd.to_datetime(df.date)
df.date = pd.to_datetime(df.date, format="%Y-%m-%d")

# %%
# Agora podemos analisar o dado mais recente do dataset
df.date.max()
# Out:
# Timestamp('2022-03-07 00:00:00')

# %% [markdown]
# Sendo mais objetivo possivel, o nosso dataset(Banco de dados) tem dados atualizados diariamente.

# %% [markdown]
# ### Formulação de novas colunas e de subdatasets

# %% [markdown]
# vamos acrescentar duas colunas no dataset, uma delas contendo o mês do registro e a outro com o ano do registro.
#
# Posteriormente, vamos criar um subdataset com os dados de 2020, 2021 e 2022 para facilitar nossas análises no futuro.
#
# Por fim, criaremos também um subdataset com os dados que tem a localização igual a “Mundo”, pois nele estão contidas todas as informações do dia no mundo, desta forma, no futuro os dados vão ser necessários.

# %%
# Adicionar as colunas mes e ano no df
df['mes'] = df.date.dt.month
df['ano'] = df.date.dt.year

# %%
#Criar subdatasets para separar os dados de 2020 e 2021
df_2020 = df[df['ano']==2020]
df_2021 = df[df['ano']==2021]
df_2022 = df[df['ano']==2022]

# %%
# Criar subdatasets para o Mundo nos anos de 2020 e 2021
df_world_2020 = df_2020[df_2020.location == 'World'].sort_values(by="total_cases", ascending=False)
df_world_2021 = df_2021[df_2021.location == 'World'].sort_values(by="total_cases", ascending=False)
df_world_2022 = df_2022[df_2022.location == 'World'].sort_values(by="total_cases", ascending=False)

# %% [markdown]
# Analisando os ultimos dados que foram acrescentados ao dados do mundo no ultimo dia de 2020 / 2021 / 2022.
#
# E assim, podemos ver a porcentagem de mortes perante a quantide total de casos.

# %%
#  Verficar os dados do ultimo dia de 2020 no mundo
df_world_2020.sort_values(by="total_cases", ascending=False).head(1)
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 164222  OWID_WRL       NaN    World 2020-12-31   83775336.0   827634.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 164222          593690.429     1881742.0     13252.0            11093.714
#
#         ...  handwashing_facilities  hospital_beds_per_thousand  \
# 164222  ...                   60.13                       2.705
#
#         life_expectancy  human_development_index  \
# 164222            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 164222                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million  mes   ano
# 164222               NaN                                      NaN   12  2020
#
# [1 rows x 69 columns]

# %% [markdown]
# O total de casos em 2020 foi de 83760090 e 1880793 mortes, o que da uma taxa de mortalidade de 2,179%.

# %%
#  Verficar os dados do ultimo dia de 2021 no mundo
df_world_2021.sort_values(by="total_cases", ascending=False).head(1)
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 164587  OWID_WRL       NaN    World 2021-12-31  288706144.0  1715008.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 164587         1323431.286     5440149.0      6008.0             6239.714
#
#         ...  handwashing_facilities  hospital_beds_per_thousand  \
# 164587  ...                   60.13                       2.705
#
#         life_expectancy  human_development_index  \
# 164587            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 164587                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million  mes   ano
# 164587               NaN                                      NaN   12  2021
#
# [1 rows x 69 columns]

# %% [markdown]
# o total de casos em 2021 foi de 288649822 e 5439860 mortes

# %%
#  Verficar os dados do ultimo dia de 2022 no mundo
df_world_2022.sort_values(by="total_cases", ascending=False).head(1)
# Out:
#         iso_code continent location       date  total_cases  new_cases  \
# 164653  OWID_WRL       NaN    World 2022-03-07  447882185.0  1602057.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 164653         1555776.286     6007317.0      7919.0             7240.714
#
#         ...  handwashing_facilities  hospital_beds_per_thousand  \
# 164653  ...                   60.13                       2.705
#
#         life_expectancy  human_development_index  \
# 164653            72.58                    0.737
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 164653                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million  mes   ano
# 164653               NaN                                      NaN    3  2022
#
# [1 rows x 69 columns]

# %% [markdown]
# o total de casos em 2022 foi de 427815880 e 5905942 mortos.

# %% [markdown]
# Nesta tabela de dados que acabamos de ver, está representada em ordem decrescente as localidades aos quais mais houve número de mortes devido a covid.
# \
# OBS: **(Os devidos sintomas ou casos agravantes que lhes causaram as mortes não estão contidas nesta pesquisa, pois tal é uma pesquisa quantitativa relacionada a quantidade de casos em relação como quantidade de vacinações, casos variados e óbitos)**.
#
#
#
#
# World \ mundo

# %% [markdown]
# Nesta célula temos a apresentação de forma decrescente do total de mortos constados no dataset, nos dando os locais onde mais houve mortos no Mundo.
# também temos o outro lado da moeda seguidamente, com os locais onde menos houve casos de mortes.

# %%
# total casos de morte 
df.loc[df.date == '2022-03-07'].sort_values(by="total_deaths", ascending=False)
# Out:
#         iso_code continent              location       date  total_cases  \
# 164653  OWID_WRL       NaN                 World 2022-03-07  447882185.0
# 159210  OWID_UMC       NaN   Upper middle income 2022-03-07  120512494.0
# 66898   OWID_HIC       NaN           High income 2022-03-07  241839742.0
# 50237   OWID_EUR       NaN                Europe 2022-03-07  162360526.0
# 112396  OWID_NAM       NaN         North America 2022-03-07   93499957.0
# ...          ...       ...                   ...        ...          ...
# 99482        FSM   Oceania  Micronesia (country) 2022-03-07          1.0
# 126136       SHN    Africa          Saint Helena 2022-03-07          4.0
# 129474       WSM   Oceania                 Samoa 2022-03-07         41.0
# 151413       TON   Oceania                 Tonga 2022-03-07       1059.0
# 161873       VAT    Europe               Vatican 2022-03-07         29.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# Efetuando a análise de quais as localidades aos quais detém o maior índice de casos de infecção da covid-19 no muno

# %%
# Analisando quais os paises que contem o maior indice de casos


df.loc[df.date == '2022-02-13'].sort_values(by="total_cases", ascending=False)

df.loc[df.date == '2022-02-13'].sort_values(by="total_deaths", ascending=False)
# Out:
#         iso_code      continent                   location       date  \
# 164631  OWID_WRL            NaN                      World 2022-02-13
# 159188  OWID_UMC            NaN        Upper middle income 2022-02-13
# 66876   OWID_HIC            NaN                High income 2022-02-13
# 50215   OWID_EUR            NaN                     Europe 2022-02-13
# 112374  OWID_NAM            NaN              North America 2022-02-13
# ...          ...            ...                        ...        ...
# 126114       SHN         Africa               Saint Helena 2022-02-13
# 129452       WSM        Oceania                      Samoa 2022-02-13
# 135617       SXM  North America  Sint Maarten (Dutch part) 2022-02-13
# 151391       TON        Oceania                      Tonga 2022-02-13
# 161851       VAT         Europe                    Vatican 2022-02-13
#
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %% [markdown]
# Primeiramente, iremos visualizar se há a existencia de outlirs em nosso dataset.

# %%
# Apurando estatisticas do dataset
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  1.637490e+05  1.636090e+05        1.616250e+05  1.458890e+05
# mean   2.552188e+06  1.160895e+04        1.161472e+04  5.783416e+04
# std    1.555033e+07  8.457752e+04        8.281271e+04  3.029782e+05
# min    1.000000e+00  0.000000e+00        0.000000e+00  1.000000e+00
# 25%    2.017000e+03  1.000000e+00        7.000000e+00  7.900000e+01
# 50%    2.626000e+04  7.900000e+01        1.072860e+02  7.850000e+02
# 75%    3.006610e+05  1.065000e+03        1.150571e+03  7.324000e+03
# max    4.478822e+08  4.206334e+06        3.444237e+06  6.007317e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  145936.000000        143838.000000            162989.000000
# mean      170.978751           172.593306             29699.304718
# std       831.636513           816.612569             52449.395497
# min         0.000000             0.000000                 0.001000
# ...

# %% [markdown]
# Pelos dados obtidos acima, podemos analizar que há Outliers em nosso dataset.
#
# -Há valores negativos presentes. \
#
# -Há a presença evidente de outliers em `New_cases`, pois o valor máxima é de 4.235025e+06. \
#
# -já nos dados onde apresentam 75% do dataset, o valor presente é de  1.048000e+03.
#
#
# No entanto, há explicações para estes fatos.
#
# * Para o caso dos valores negativos, eles significam que quando a organização que registrou os dados, registrava dados a mais, no outro dia eles subtraiam para ter um valor mais aproximado do da realidade. Dessa forma, não vamos excluir os dados negativos, pois eles fazem sentido e são importantes!
#
# * Por outro lado, os outliers são os dados que possuem localização igual a “Mundo ”, assim como já separamos esses dados em subdataframes vamos exclui-los. Para isso, iremos transformar o atributo `location` no index e depois excluir os dados World.

# %%
# Transformar a coluna location no index
df_2020.set_index('location', inplace=True)
df_2021.set_index('location', inplace=True)
df_2022.set_index('location', inplace=True)

# %%
# Excluindo os dados do mundo
df_2020 = df_2020.drop("World")
df_2021 = df_2021.drop("World")
df_2022 = df_2022.drop("World")

# %% [markdown]
# #Análise do Mundo em 2022
#
# Como podemos analisar, o dado mais recentefoi comitado em 22/02/2022. Vamos ver alguns dados concretos nos quais apresentam os maiores valores atingidos durante a pandemia até esse dia.

# %%
print('O número total de casos registrados foi de {:.0f} casos!'.format(df.total_cases.max()))
print('O número máximo de mortes registradas foi de {:.0f} mortes!'.format(df.total_deaths.max()))
print('O número máximo de descobertas de novos casos em um dia foi de {:.0f} casos!'.format(df_world_2022.new_cases.max()))
print('O número máximo de mortes em um único dia foi de {:.0f} casos!'.format(df_world_2020.new_deaths.max()))
# Out:
# O número total de casos registrados foi de 447882185 casos!
# O número máximo de mortes registradas foi de 6007317 mortes!
# O número máximo de descobertas de novos casos em um dia foi de 4206334 casos!
# O número máximo de mortes em um único dia foi de 15633 casos!

# %% [markdown]
# Em sintese, os dados numericamente postos sendo vizualizados já parecem ser absurdamente preocupante e assustadores. Infelizmente hoje ja perdemos a senssibilidade de mensurar que uma centena de pessoas são realmente 100 pessoas, 100 vidas, 100 seres humanos que poderiam ser ou estar sendo a diferença para algo significante para o mundo ou para você. Esta é apenas uma reflexão corroborando a volta da senssibilidade a qual perdemos.
#
# Outrossim, a primeira coisa que camos analisar são os dados de 2020

# %% [markdown]
# # Quantidade de Casos / Mortes

# %% [markdown]
# Em 2020 queremos analisar muitas coisas, desde como foi o crescimento do número de casos e mortes, comparando esses números em cada continente, até análise das mortes com relação ao IDH e expectativa de vida do País. Visto isso, vamos dar uma olhada também nas informações dos hospitais.

# %%
print('O número total de casos registrados em 2020 foi de {:.0f} casos!'.format(df_2020.new_cases.sum()))
# Out:
# O número total de casos registrados em 2020 foi de 264905165 casos!

# %% [markdown]
# Abaixo veremos o total de novos casos por mês em 2020, 2021 e 2022.

# %%
# Casos por mes 
print('No mês de dezembro de 2020 tivemos o maior número de novos casos, com {:.0f} casos!'.format(df_2020[df_2020['mes']==12].new_cases.sum())) 
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar",ci="sd", palette="dark", alpha=.9, height=8, data=df_2020); 
plt.title('Gráfico da quantidade de Casos por Mês');
# Out:
# No mês de dezembro de 2020 tivemos o maior número de novos casos, com 62654142 casos!

# %%
# Casos por mes 
print('No mês de dezembro de 2021 tivemos o maior número de novos casos, com {:.0f} casos!'.format(df_2021[df_2021['mes']==12].new_cases.sum())) 
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar",ci="sd", palette="dark", alpha=.9, height=8, data=df_2021); 
plt.title('Gráfico da quantidade de Casos por Mês');
# Out:
# No mês de dezembro de 2021 tivemos o maior número de novos casos, com 86204993 casos!

# %%
# Casos por mes 
print('No mês de dezembro de 2022 tivemos o maior número de novos casos, com {:.0f} casos!'.format(df_2022[df_2022['mes']==12].new_cases.sum())) 
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar",ci="sd", palette="dark", alpha=.9, height=8, data=df_2022); 
plt.title('Gráfico da quantidade de Casos por Mês');
# Out:
# No mês de dezembro de 2022 tivemos o maior número de novos casos, com 0 casos!

# %% [markdown]
# Pelos gráficos acima, é nitido o crescimento giganesto de quantidade de casos com o passar do tempo em 2020.
# Em 2021 o ano já começa com a quantidade de casos extremamente alta, resultado de datas festivas.
# Porem, podemos ver uma similaridade entre os gráficos que representam dois anos diferentes, pois ambos apresentam seu pico de novos casos no mes de Dezembro.
# Já em 2022 vemos o mes de Fevereiro ter um número menor de casos em comparação a Janeiro, assim, nos encontramos em uma queda no número de casos

# %% [markdown]
# Seguidamente veremos graficos representando a quantidade de mortos pelo covid.

# %%
print('O número total de mortes registradas em 2020 foi de {:.0f} mortes!'.format(df_2020.new_deaths.sum()))
# Out:
# O número total de mortes registradas em 2020 foi de 6003782 mortes!

# %%
print('O número total de mortes registradas em 2021 foi de {:.0f} mortes!'.format(df_2021.new_deaths.sum()))
# Out:
# O número total de mortes registradas em 2021 foi de 11150591 mortes!

# %%
# Mortes por mes
print('No mês de dezembro de 2020 tivemos o maior número de mortes, com {:.0f} mortes!!'.format(df_2020[df_2020['mes']==12].new_deaths.sum())) 
sns.catplot(x="mes", y="new_deaths", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Gráfico da quantidade de Mortes por Mês');
# Out:
# No mês de dezembro de 2020 tivemos o maior número de mortes, com 1170640 mortes!!

# %%
# Mortes por mes
print('No mês de janeiro de 2021 tivemos o maior número de mortes, com {:.0f} mortes!!'.format(df_2021[df_2021['mes']==1].new_deaths.sum())) 
sns.catplot(x="mes", y="new_deaths", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2021);
plt.title('Gráfico da quantidade de Mortes por Mês');
# Out:
# No mês de janeiro de 2021 tivemos o maior número de mortes, com 1352444 mortes!!

# %%
# Mortes por mes
print('No mês de janeiro de 2022 tivemos o maior número de mortes, com {:.0f} mortes!!'.format(df_2022[df_2022['mes']==1].new_deaths.sum())) 
sns.catplot(x="mes", y="new_deaths", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Gráfico da quantidade de Mortes por Mês');
# Out:
# No mês de janeiro de 2022 tivemos o maior número de mortes, com 762653 mortes!!

# %% [markdown]
# O gráfico é muito interessante para ser analisado, pois embora a quantidade de casos tenha crescido constantemente (como vimos no gráfico anterior), vemos que o mês de abril teve um número maior de mortes do que maio, junho, julho, agosto, setembro e outubro, em ambos os anos.
#
# Fato interessante, mas totalmente explicável. O motivo? A declaração oficial que a covid tinha virado pandemia, veio em meados de março e com ela vieram também lockdown no mundo assim como as campanhas intensivas de conscientização, com isso ainda não estávamos (população e o estado) tão preparados para conter o vírus. Com o tempo, vemos que as medidas surtiram efeito, porém com o aumento gigantesco do número de ocorrências em novembro e dezembro a quantidade de mortes voltou a crescer. Já em 2021, os casos de obitos virem de forma contraria ao crescimento de novos caso de contaminação graças a forte campanha de vacinação, pois com a inicialização da vacinação podemos **AFIRMAR** que foi de suma importancia para a queda do numero de mortos.
#
# Vemos uma quebra na curva linear em que estavamos observando referente ao número de mortes devido ao mês de Fevereiro em que foi maior do que a de Janeiro. Devemos colher mais dados futuros para que se possa chegar em alguma conclusão palpavel.

# %% [markdown]
# Posteriormente, vamos analisar os dados referente aos hospitais durante o ano de 2020 e 2021.

# %% [markdown]
# ###  Hospitais:

# %% [markdown]
# Anteriormente anaisamos os casos de contaminação e óbitos no mundo.
#
# A seguir veremos como os casos de internação e total de camas por milhao se mostram em cada mes nos anos de 2020 e 2021

# %%
# Total de Pacientes de Hospitais por Milhão de Pessoas em 2020
sns.catplot(x="mes", y="hosp_patients_per_million", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Total de Pacientes de Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %%
# Total de Pacientes de Hospitais por Milhão de Pessoas em 2021
sns.catplot(x="mes", y="hosp_patients_per_million", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2021);
plt.title('Total de Pacientes de Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %%
# Total de Pacientes de Hospitais por Milhão de Pessoas em 2022
sns.catplot(x="mes", y="hosp_patients_per_million", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Total de Pacientes de Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %% [markdown]
# Nos gráficos acima, podemos constatar uma lineariedade de casos pois em abril na comparação total de mortos e contabilização de pacientes, ambos tiveram um grande registro em abril, posteriormente caindo nos meses seguintes, mas tendo um crescimento gigantesco a partir julho e agosto. Mas ocorreu uma quebra dessa linearidade em 2022 com o mês de Fevereiro.
#
# Os casos de pacientes das UTIS dos hospitais por milhão de pessoas por mes.

# %%
#Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas em 2020
sns.catplot(x="mes", y="icu_patients_per_million", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %%
#Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas em 2021
sns.catplot(x="mes", y="icu_patients_per_million", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2021);
plt.title('Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %%
#Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas em 2022
sns.catplot(x="mes", y="icu_patients_per_million", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Total de Pacientes dos UTIS dos Hospitais por Milhão de Pessoas');
plt.tight_layout()
plt.show()

# %% [markdown]
# Por fim, vamos visualizar o gráfico referente ao Total de Camas de Hospital por Mil Pessoas. Com ele, podemos ver que desde março, o número de camas disponibilizadas por mês ficou parecida em 2020 e 2021. Já em 2022 o número de pacientes em UTI's são inferiores a 2021 comparando os meses iniciais.

# %%
#Total de Camas de Hospitais por Mil Pessoas
sns.catplot(x="mes", y="hospital_beds_per_thousand", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Total de Camas de Hospitais por Mil Pessoas');
plt.tight_layout()
plt.show()

# %%
#Total de Camas de Hospitais por Mil Pessoas
sns.catplot(x="mes", y="hospital_beds_per_thousand", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2021);
plt.title('Total de Camas de Hospitais por Mil Pessoas');
plt.tight_layout()
plt.show()

# %%
#Total de Camas de Hospitais por Mil Pessoas
sns.catplot(x="mes", y="hospital_beds_per_thousand", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Total de Camas de Hospitais por Mil Pessoas');
plt.tight_layout()
plt.show()

# %% [markdown]
# Neste gráfico acima, vemos a definição de um sistema de saude em colapso, pois todos os meses veio se apresentando com números extrondosos. Podemos observar também que em 2022 o número de óbitos é superior ao número de internações no mês de Fevereiro.

# %% [markdown]
# ##Visualização Geográfica

# %% [markdown]
# ###Visualização por Continente
#
# Antes de tudo, vamos analisar como ficou a distribuição da quantidade de casos/mortes por continente.

# %%
# Total de casos de 2020 em cada continente
print('Ao fim de 2020, a Europa teve o maior número de novos casos, com {:.0f} casos!'.format(df_2020[df_2020['continent']=='Europe'].new_cases.sum())) 
sns.catplot(x="continent", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Gráfico da quantidade de Casos por Continente em 2020');
# Out:
# Ao fim de 2021, a Europa teve o maior número de novos casos, com 23955477 casos!

# %%
# Total de casos de 2021 em cada continente
print('Ao fim de 2021, a Europa teve o maior número de novos casos, com {:.0f} casos!'.format(df_2021[df_2021['continent']=='Europe'].new_cases.sum())) 
sns.catplot(x="continent", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2021);
plt.title('Gráfico da quantidade de Casos por Continente em 2021');
# Out:
# Ao fim de 2021, a Europa teve o maior número de novos casos, com 65215189 casos!

# %%
# Total de casos de 2022 em cada continente
print('Ao fim de 2022, a Europa teve o maior número de novos casos, com {:.0f} casos!'.format(df_2022[df_2022['continent']=='Europe'].new_cases.sum())) 
sns.catplot(x="continent", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Gráfico da quantidade de Casos por Continente em 2022');
# Out:
# Ao fim de 2022, a Europa teve o maior número de novos casos, com 72874580 casos!

# %%
# Total de mortes de 2020 em cada continente
print('Ao fim de 2020, a Europa teve o maior número de mortes por covid, com {:.0f} casos!'.format(df_2020[df_2020['continent']=='Europe'].new_deaths.sum())) 
sns.catplot(x="continent", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2020);
plt.title('Gráfico da quantidade de Mortes por Continente');
# Out:
# Ao fim de 2020, a Europa teve o maior número de mortes por covid, com 547198 casos!

# %%
# Total de Mortos de 2021 em cada continente
print('Ao fim de 2021, a Europa Também teve o maior número de mortes por covid, com {:.0f} casos!'.format(df_2021[df_2021['continent']=='Europe'].new_deaths.sum())) 
sns.catplot(x="continent", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Gráfico da quantidade de Mortes por Continente');
# Out:
# Ao fim de 2021, a Europa Também teve o maior número de mortes por covid, com 984709 casos!

# %%
# Total de Mortos de 2022 em cada continente
print('Ao fim de 2022, a Europa Também teve o maior número de mortes por covid, com {:.0f} casos!'.format(df_2022[df_2022['continent']=='Europe'].new_deaths.sum())) 
sns.catplot(x="continent", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=8, data=df_2022);
plt.title('Gráfico da quantidade de Mortes por Continente');
# Out:
# Ao fim de 2022, a Europa Também teve o maior número de mortes por covid, com 197157 casos!

# %% [markdown]
# Com a visualizção destes gráficos, podemos notar a dominancia Europeia em relação a contaminação e mortes devido ao covid. Não deixando de lado a Asia, América do Norte e América do Sul que estão bem próximas de atingir o mesmo patamar.

# %% [markdown]
# ## Países:

# %% [markdown]
# A seguir, estará representado os 5 paises aos quais detem os maiores números de Casos/Mortes

# %%
# Top 5 paises no numero de casos
top_5_cases = df.loc[df.date == '2021-12-31', ['location', 'total_cases']].sort_values(by="total_cases", ascending=False)[1:13]
top_5_cases.reset_index(inplace=True)
top_5_cases.drop([0, 1, 2, 4, 5, 9, 11], inplace=True)
fig, ax = plt.subplots(figsize=(10,6))

ax.bar('location', 'total_cases', data=top_5_cases)

plt.tight_layout()
plt.title('Top 5 países no número de casos');

# %% [markdown]
# Neste gráfico acima, vemos que a Asia leva o primeiro lugar, com cerca de mais de 80 milhoes de casos, seguido pela União Européia, Estados Unidos, América do Sul e Brasil.

# %% [markdown]
# Vemos a seguir os Top 5 em casos e mortes no mundo

# %%
# Top 5 paises no numero de mortes
top_5_death = df.loc[df.date == '2021-12-31', ['location', 'total_deaths']].sort_values(by="total_deaths", ascending=False)[1:13]
top_5_death.reset_index(inplace=True)
top_5_death.drop([0, 1, 2, 3, 5, 10,11], inplace=True)
fig, ax = plt.subplots(figsize=(10,6))

ax.bar('location', 'total_deaths', data=top_5_death)

plt.tight_layout()
plt.title('Top 5 países no número de mortes');

# %% [markdown]
# Por fim, verificamos que os Estados Unidos Lideram o ranking de países com o maior inice de mortes no mundo, seguido pela América do Sul, União Européia, Estados Unidos e Brasil.

# %% [markdown]
# ##Índice de desenvolvimento de Países

# %% [markdown]
# Após a análise de 2020 e 2021, vamos verificar a relação entre o IDH e a expectativa de vida coorrelacionano com número de Casos/Mortes.

# %% [markdown]
# IDH

# %% [markdown]
# Pelos gráficos abaixo, percebemos uma alta quantidade de casos/mortes para os países cujo IDH converge para 1, mas isso se dá por conta dos grandes números dos EUA. Por outro lado, podemos levar em consideração também os outros picos, os quais são para os países de IDH de aproximadamente 0.65 e 0.78.

# %%
#Casos por IDH 2020
fig, ax = plt.subplots(figsize=(12,5))
df_2020.plot.scatter(x="human_development_index", y="total_cases", ax=ax)
plt.title('Casos por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Casos por IDH 2021
fig, ax = plt.subplots(figsize=(12,5))
df_2021.plot.scatter(x="human_development_index", y="total_cases", ax=ax)
plt.title('Casos por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Casos por IDH 2022
fig, ax = plt.subplots(figsize=(12,5))
df_2022.plot.scatter(x="human_development_index", y="total_cases", ax=ax)
plt.title('Casos por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por IDH 2020
fig, ax = plt.subplots(figsize=(12,5))
df_2020.plot.scatter(x="human_development_index", y="total_deaths", ax=ax)
plt.title('Mortes por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por IDH 2021
fig, ax = plt.subplots(figsize=(12,5))
df_2021.plot.scatter(x="human_development_index", y="total_deaths", ax=ax)
plt.title('Mortes por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por IDH 2022
fig, ax = plt.subplots(figsize=(12,5))
df_2022.plot.scatter(x="human_development_index", y="total_deaths", ax=ax)
plt.title('Mortes por IDH');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# Vemos uma semelhança bem forte entre o número de casos e mortes, nos indicando que ambas, possivelmente, caminhem juntas ou próximas.

# %% [markdown]
# ### Expectativa de vida

# %%
#Casos por Expectativa de Vida 2020
fig, ax = plt.subplots(figsize=(12,5))
df_2020.plot.scatter(x="life_expectancy", y="total_cases", ax=ax,)
plt.title('Casos por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Casos por Expectativa de Vida 2021
fig, ax = plt.subplots(figsize=(12,5))
df_2021.plot.scatter(x="life_expectancy", y="total_cases", ax=ax,)
plt.title('Casos por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Casos por Expectativa de Vida 2022
fig, ax = plt.subplots(figsize=(12,5))
df_2022.plot.scatter(x="life_expectancy", y="total_cases", ax=ax,)
plt.title('Casos por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por Expectativa de Vida 2020
fig, ax = plt.subplots(figsize=(12,5))
df_2020.plot.scatter(x="life_expectancy", y="total_deaths", ax=ax)
plt.title('Mortes por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por Expectativa de Vida 2021
fig, ax = plt.subplots(figsize=(12,5))
df_2021.plot.scatter(x="life_expectancy", y="total_deaths", ax=ax)
plt.title('Mortes por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %%
#Mortes por Expectativa de Vida 2022
fig, ax = plt.subplots(figsize=(12,5))
df_2022.plot.scatter(x="life_expectancy", y="total_deaths", ax=ax)
plt.title('Mortes por Expectativa de Vida');
fig.autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# Com estes gráficos, podemos notar que a quantidade de casos e mortes está concentrada em pssoas com média de idade entre 70 e 80 anos dentre o periodo pandêmico ao qual nós ainda nos encontramos.

# %% [markdown]
# #Vacina
#
# A seguir, vamos analisar a relação das vacinas durante todo o periodo a qual temos dados.

# %%
# Data da pimeira vacina
df_vac = df.copy()
df_vac.set_index('location', inplace=True)
df_vac = df_vac.drop("World")
df_vac.dropna(subset=['people_vaccinated'], axis=0, inplace=True)
df_vac.sort_values(by="date", ascending=True).head(12)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#                 iso_code continent       date  total_cases  new_cases  \
# location
# Europe          OWID_EUR       NaN 2020-12-02   17756370.0   212640.0
# Norway               NOR    Europe 2020-12-02      36969.0      378.0
# High income     OWID_HIC       NaN 2020-12-02   29966773.0   363523.0
# Europe          OWID_EUR       NaN 2020-12-03   17982340.0   225970.0
# High income     OWID_HIC       NaN 2020-12-03   30359361.0   392588.0
# Norway               NOR    Europe 2020-12-03      37371.0      402.0
# Latvia               LVA    Europe 2020-12-04      19993.0      686.0
# ...

# %% [markdown]
# A primeira vacina registrada nos dados foi em 04/12/2020, na Europa.

# %% [markdown]
# ###Quantidade de vacinas produzidas e distribuidas

# %%
# Total de vacinadas produzidas
print('__Até hoje, cerca de {:.0f} vacinas foram produziadas!'.format(df_world_2021.total_vaccinations.values[0]))
# Out:
# __Até hoje, cerca de 9170899839 vacinas foram produziadas!

# %%
# Total de pessoas vacinadas registradas
print('Até hoje, cerca de {} pessoas foram vacinadas!'.format(df_world_2022.people_vaccinated.values[0]))
# Out:
# Até hoje, cerca de 4988664787.0 pessoas foram vacinadas!

# %%
# vamos ver a quantidade de pessoas TOTALMENTE Vacinadas.
print('Até hoje, cerca de {} pessoas foram totalmente vacinadas!'.format(df_world_2022.people_fully_vaccinated.values[0]))
# Out:
# Até hoje, cerca de 4418225173.0 pessoas foram totalmente vacinadas!

# %% [markdown]
# #**Quadro do brasil referente aos casos do covid 19**

# %% [markdown]
# Antes de tudo, criaremos um subdataset só com os dados do Brasil

# %%
df_brasil_2020 = df_2020.loc["Brazil"].sort_values(by="total_cases", ascending=True).copy()
df_brasil_2021 = df_2021.loc["Brazil"].sort_values(by="total_cases", ascending=True).copy()
df_brasil_2022 = df_2022.loc["Brazil"].sort_values(by="total_cases", ascending=True).copy()

# %% [markdown]
# Analisaremos a primeira ocorrencia de covid registrado no Brasil

# %%
df_brasil_2020.head(1)
# Out:
#          iso_code      continent       date  total_cases  new_cases  \
# location
# Brazil        BRA  South America 2020-02-26          1.0        1.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# location
# Brazil                   NaN           NaN         NaN                  NaN
#
#           total_cases_per_million  ...  handwashing_facilities  \
# location                           ...
# Brazil                      0.005  ...                     NaN
#
#           hospital_beds_per_thousand  life_expectancy  \
# location
# Brazil                           2.2            75.88
#
#           human_development_index  excess_mortality_cumulative_absolute  \
# location
# Brazil                      0.765                                   NaN
#
#           excess_mortality_cumulative  excess_mortality  \
# location
# Brazil                            NaN               NaN
#
#           excess_mortality_cumulative_per_million  mes   ano
# ...

# %% [markdown]
# Tivemos o primiro caso registrado no Brasil em 2020 no dia 26 de Fevereiro.

# %%
# Distribuição de casos em 2020
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2020);
plt.title("Distribuição dos casos por mês no Brasil durante 2020");

# %%
# Distribuição de casos em 2021
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2021);
plt.title("Distribuição dos casos por mês no Brasil durante 2021");

# %%
# Distribuição de casos em 2022
sns.catplot(x="mes", y="new_cases", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2022);
plt.title("Distribuição dos casos por mês no Brasil durante 2022");

# %% [markdown]
# diante dos gráficos, percebemos que o de 2020 está bem diferente aos dados mundiais. Tal diferença é causada pois o vírus demorou um tempo consideravel até atingir a população brasileira. Tambem, outro fato a ser ressaltado é que os caso do Brasil destoam bastante do mundo como podemos ver uma crescente até julho, e os casos até novembro se encontram em queda.
#
# No ano de 2021 os números de casos no mundo é praticamente linear, se mantendo em uma linha, já no Brasil, podemos ver uma queda constante des de Junho. Já em 2022 os casos já são proporcionalmente mais comparáveis.

# %% [markdown]
# Veremos abaixo, a relação do crescimento de casos no Brasil

# %%
print('O número total de novos casos de dezembro de 2020 foi de {:.0f} casos !'.format(df_brasil_2020[df_brasil_2020['mes']==12].new_cases.sum()))
print('O número total de novos casos de dezembro de 2021 foi de {:.0f} casos !'.format(df_brasil_2021[df_brasil_2021['mes']==12].new_cases.sum()))
print('O número total de novos casos de Fevereiro de 2022 foi de {:.0f} casos !'.format(df_brasil_2022[df_brasil_2022['mes']==2].new_cases.sum()))
# Out:
# O número total de novos casos de dezembro de 2020 foi de 1339067 casos !
# O número total de novos casos de dezembro de 2021 foi de 191696 casos !
# O número total de novos casos de Fevereiro de 2022 foi de 3333041 casos !

# %% [markdown]
# >Mortes por mês no Brasil durante todo o periodo pandemico.

# %%
sns.catplot(x="mes", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2020);
plt.title("Distribuição das mortes por mês no Brasil durante 2020");

# %%
sns.catplot(x="mes", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2021);
plt.title("Distribuição das mortes por mês no Brasil durante 2021");

# %%
sns.catplot(x="mes", y="new_deaths", estimator=sum, kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2022);
plt.title("Distribuição das mortes por mês no Brasil durante 2022");

# %% [markdown]
# Assim, com a apresentação dos gráficos referente aos anos, podemos notar a similaridade entre os casos e mortes durante todo o período a qual temos registro.

# %%
# Comparação de casos de mortes durante Dezembro de 2021 à Fevereiro de 2022
print('O número total de novas mortes de dezembro de 2021 foi de {:.0f} mortes !'.format(df_brasil_2021[df_brasil_2021['mes']==12].new_deaths.sum()))
print('O número total de novas mortes de Março de 2022 foi de {:.0f} mortes !'.format(df_brasil_2022[df_brasil_2022['mes']==3].new_deaths.sum()))
# Out:
# O número total de novas mortes de dezembro de 2021 foi de 4349 mortes !
# O número total de novas mortes de Março de 2022 foi de 2972 mortes !

# %% [markdown]
# A quantidade de mortos como podemos ver, vem caindo!

# %% [markdown]
# >Vacinas

# %%
# Pessoas vacinadas em 2021
sns.catplot(x="mes", y="people_vaccinated", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2021);
plt.title("Pessoas Vacinadas por Mês em 2021");

# %%
# Pessoas vacinadas em 2021
sns.catplot(x="mes", y="people_vaccinated", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2022);
plt.title("Pessoas Vacinadas por Mês em 2022");

# %% [markdown]
# Assim vemos que a quantidade de pessoas vacinadas está em uma crescente. Como esta pesquisa detem de dados que vão até dia 08/03/2022 os dados referentes a Março estarão incompletos, mas mesmo com esta situação temos dados e representações fidedignas.

# %%
# Pessoas totalmente vacinadas em 2021
sns.catplot(x="mes", y="people_fully_vaccinated", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2021);
plt.title("Pessoas Totalmente Vacinadas por Mês em 2021");

# %% [markdown]
# Podemos notar que a vacinação das Duas doses na população veio a demorar mais devio ao tempo de espera entre as doses, mas estamos em uma crescente em relação ao número de total de vacinados. Um fator de suma importancia ressaltar é a queda de mortes e casos em decorrencia da alta de vacinados.

# %%
# Pessoas totalmete vacinadas em 2022
sns.catplot(x="mes", y="people_fully_vaccinated", estimator=sum ,kind="bar", ci="sd", palette="dark", alpha=.9, height=7,data=df_brasil_2022);
plt.title("Pessoas Totalmente Vacinadas por Mês em 2022");

# %% [markdown]
# Em 2022 o total de Vacinados apresenta a mesma caracteristica do ano anterior, basta aguardar a obtenção de mais dados ao decorrer dos meses para ter uma análise mais palpavel referente ao ano de 2022.

# %% [markdown]
# #**Conclusão**

# %% [markdown]
# ###Casos e Mortes

# %% [markdown]
# Em suma. Ao final do projeto, faremos uma retrospectiva do que analisamos durante a pesquisa realizada. Gráficos referente á quantidade de casos e mortes foram os protagonistas da pesquisa, por terem uma relevancia astronomica, pois é algo que afeta tanto uma sociedade inteira quato um indivíduo.

# %% [markdown]
# ![image.png](data:image/png;base64,...)![image.png](data:image/png;base64,...),  ![image.png](data:image/png;base64,...)

# %% [markdown]
# Estes gráficos acima são referentes a quantidade de casos durante o ano de 2020, 2021 e 2022. Podemos ver que tivemos um padrão de crescimento grande em 2020, uma estabilização com oscilações grandes a cada mês em 2021. Em 2022 os dados se apresentam em queda.

# %% [markdown]
# ![image.png](data:image/png;base64,...), ![image.png](data:image/png;base64,...), ![image.png](data:image/png;base64,...)

# %% [markdown]
# Estas formas de gráficos referentes a quantidade de mortos no tempo pandêmico a qual temos dados, Podemos ver uma semelhança entre os gráficos de casos e mortes, porém, os números de mortos apresentam uma queda a partir do mês Setembro de 2021.
#
# Os dados obtidos no projeto podem ser material de tomada de decisão por especialistas responsáveis pelas Covid, pois tais apresentam linearidade entre os dados, podendo assim, possivelmente interpretar algum quadro situacional a qual uma pessoa com apenas conhecimentos básicos não conseguiria ter o feeling suficiente.
